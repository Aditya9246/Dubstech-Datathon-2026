# %%
import pandas as pd

file_path = '/Users/nipun/Projects/Health_Datathon'
# 1. Reload the data
df = pd.read_csv(
    file_path + '/data/NHIS_Data.csv', engine="pyarrow")

# 2. Check the types
print(df.dtypes)
# Out:
# TOPIC                    str
# SUBTOPIC                 str
# SUBTOPIC_ID          float64
# TAXONOMY                 str
# TAXONOMY_ID            int64
# CLASSIFICATION           str
# CLASSIFICATION_ID      int64
# GROUP                    str
# GROUP_ID               int64
# GROUP_ORDER            int64
# SUBGROUP                 str
# SUBGROUP_ID            int64
# SUBGROUP_ORDER         int64
# NESTING_LABEL            str
# NESTING_LABEL_ID     float64
# ESTIMATE_TYPE            str
# ESTIMATE_TYPE_ID       int64
# TIME_PERIOD            int64
# TIME_PERIOD_ID       float64
# ESTIMATE             float64
# STANDARD_ERROR       float64
# ESTIMATE_LCI         float64
# ESTIMATE_UCI         float64
# FLAG                     str
# FOOTNOTE_ID_LIST         str
# dtype: object

# %%
# Strip spaces from all column names
df.columns = df.columns.str.strip()
cols_to_drop = ['SUBTOPIC', 'SUBTOPIC_ID', 'NESTING_LABEL', 'NESTING_LABEL_ID', 'FLAG', 'ESTIMATE_TYPE_ID', 'TIME_PERIOD_ID', 'STANDARD_ERROR']
df.drop(columns=cols_to_drop, inplace=True,)
df.head()
# Out:
#                     TOPIC                 TAXONOMY  TAXONOMY_ID  \
# 0  Angina/angina pectoris  Cardiovascular diseases           60
# 1  Angina/angina pectoris  Cardiovascular diseases           60
# 2  Angina/angina pectoris  Cardiovascular diseases           60
# 3  Angina/angina pectoris  Cardiovascular diseases           60
# 4  Angina/angina pectoris  Cardiovascular diseases           60
#
#   CLASSIFICATION  CLASSIFICATION_ID  GROUP  GROUP_ID  GROUP_ORDER  \
# 0          Total                  0  Total         1            1
# 1          Total                  0  Total         1            1
# 2          Total                  0  Total         1            1
# 3          Total                  0  Total         1            1
# 4          Total                  0  Total         1            1
#
#              SUBGROUP  SUBGROUP_ID  SUBGROUP_ORDER  \
# 0  18 years and older            1               1
# 1  18 years and older            1               1
# 2  18 years and older            1               1
# 3  18 years and older            1               1
# 4  18 years and older            1               1
#
#                   ESTIMATE_TYPE  TIME_PERIOD  ESTIMATE  ESTIMATE_LCI  \
# 0  Percent of population, crude         2019       1.7           1.5
# 1  Percent of population, crude         2020       1.5           1.3
# 2  Percent of population, crude         2021       1.5           1.4
# 3  Percent of population, crude         2022       1.6           1.5
# 4  Percent of population, crude         2023       1.6           1.4
#
#    ESTIMATE_UCI                              FOOTNOTE_ID_LIST
# 0           1.9  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 1           1.6  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 2           1.7  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 3           1.8  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00
# 4           1.8  NT_NHISA00,NT_NHISA999,FN_NHISA18,SC_NHISA00

# %%
df.head()
df.columns
df.shape
# Out:
# (26208, 17)

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# ESTIMATE_UCI         0.098252
# ESTIMATE_LCI         0.098252
# ESTIMATE             0.090392
# TOPIC                0.000000
# SUBGROUP_ID          0.000000
# TIME_PERIOD          0.000000
# ESTIMATE_TYPE        0.000000
# SUBGROUP_ORDER       0.000000
# SUBGROUP             0.000000
# TAXONOMY             0.000000
# GROUP_ORDER          0.000000
# GROUP_ID             0.000000
# GROUP                0.000000
# CLASSIFICATION_ID    0.000000
# CLASSIFICATION       0.000000
# TAXONOMY_ID          0.000000
# FOOTNOTE_ID_LIST     0.000000
# dtype: float64

# %%
print(df['TOPIC'].unique()) # See what barriers are available
# Out:
# <StringArray>
# [                                                       'Angina/angina pectoris',
#                                                                'Any cancer type',
#                                                   'Any difficulty communicating',
#                                                         'Any difficulty hearing',
#                                    'Any difficulty remembering or concentrating',
#                                                          'Any difficulty seeing',
#                                       'Any difficulty walking or climbing steps',
#                                                  'Any difficulty with self care',
#                                                                'Any skin cancer',
#                                                            'Arthritis diagnosis',
#                                                'Asthma episode/attack in adults',
#                                                           'Blood pressure check',
#                                                                  'Breast cancer',
#                                            'COPD, emphysema, chronic bronchitis',
#                                                                'Cervical cancer',
#                                                         'Coronary heart disease',
#                                      'Counseled by a mental health professional',
#                                                       'Current asthma in adults',
#                                                      'Current cigarette smoking',
#                             'Current electronic cigarette or vaping product use',
#                          'Delayed getting medical care due to cost among adults',
#                                                        'Dental exam or cleaning',
#                                              'Diabetes diagnosis, self-reported',
#                                    'Did not get needed medical care due to cost',
#                              'Did not get needed mental health care due to cost',
#                            'Did not take medication as prescribed to save money',
#                                     'Disability status (composite) among adults',
#                                                      'Doctor visit among adults',
#                                       'Ever received a pneumococcal vaccination',
#                      'Exchange-based coverage at time of interview among adults',
#                                           'Fair or poor health status in adults',
#                       'Functioning difficulties status (composite) among adults',
#                                         'Has a usual place of care among adults',
#                                             'Heart attack/myocardial infarction',
#                                      'High cholesterol diagnosis, self-reported',
#                                            'Hospital emergency department visit',
#                                          'Hypertension diagnosis, self-reported',
#                                               'Obesity in adults, self-reported',
#                                       'Prescription medication use among adults',
#            'Private health insurance coverage at time of interview among adults',
#                                                                'Prostate cancer',
#             'Public health insurance coverage at time of interview among adults',
#                                  'Receipt of influenza vaccination among adults',
#                                             'Regularly experienced chronic pain',
#                                           'Regularly had feelings of depression',
#                       'Regularly had feelings of worry, nervousness, or anxiety',
#              'Six or more workdays missed due to illness, injury, or disability',
#                      'Taking prescription medication for feelings of depression',
#  'Taking prescription medication for feelings of worry, nervousness, or anxiety',
#                                    'Uninsured at time of interview among adults',
#                      'Uninsured for at least part of the past year among adults',
#                                  'Uninsured for more than one year among adults',
#                 'Urgent care center or retail health clinic visit among adults:',
#                                                                 'Wellness visit']
# Length: 54, dtype: str

# %%
print(df['SUBGROUP'].unique()) # See which demographics you can analyze
# Out:
# <StringArray>
# [                            '18 years and older',
#                                     '18-34 years',
#                                     '35-49 years',
#                                     '50-64 years',
#                              '65 years and older',
#                                     '18-44 years',
#                                     '45-64 years',
#                                     '65-74 years',
#                              '75 years and older',
#                                 'With disability',
#                              'Without disability',
#                   'With functioning difficulties',
#                'Without functioning difficulties',
#                                         'Married',
#                           'Divorced or separated',
#                                         'Widowed',
#                           'Living with a partner',
#                                   'Never married',
#                                       'U.S.-born',
#                                    'Foreign-born',
#          'American Indian and Alaska Native only',
#                                      'Asian only',
#                                      'Black only',
#  'Native Hawaiian or Other Pacific Islander only',
#                                      'White only',
#     'American Indian and Alaska Native and White',
#                                 'Black and White',
#                             'All races, Hispanic',
#                    'All races, Hispanic, Mexican',
#                         'All races, non-Hispanic',
#                        'Black only, non-Hispanic',
#                        'White only, non-Hispanic',
#                       'Other races, non-Hispanic',
#                                          'Female',
#                                            'Male',
#                                        'Bisexual',
#                                  'Gay or Lesbian',
#                                        'Straight',
#                                         'Veteran',
#                                     'Non-veteran',
#                                       'Large MSA',
#                                       'Small MSA',
#                                         'Non-MSA',
#                                       'Northeast',
#                                         'Midwest',
#                                           'South',
#                                            'West',
#               'Little to no social vulnerability',
#                        'Low social vulnerability',
#                     'Medium social vulnerability',
#                       'High social vulnerability',
#                             'Large central metro',
#                              'Large fringe metro',
#                          'Medium and small metro',
#                                 'Nonmetropolitan',
#                   'No high school diploma or GED',
#                      'High school diploma or GED',
#                                    'Some college',
#                        'College degree or higher',
#                                        'Employed',
#                            'Employed - Full-time',
#                            'Employed - Part-time',
#                                    'Not employed',
#            'Not employed - Has worked previously',
#                 'Not employed - Has never worked',
#                                         'Private',
#                           'Medicare and Medicaid',
#                              'Medicare Advantage',
#      'Medicare only excluding Medicare Advantage',
#                       'Other government coverage',
#                                       'Uninsured',
#                'Medicaid or other state programs',
#                                       '<100% FPL',
#                               '100% to <200% FPL',
#                                       '≥200% FPL']
# Length: 75, dtype: str

# %%
df.head()
df.columns
df.shape
# Out:
# (26208, 17)

# %%
df.to_csv(file_path + '/data/NHIS_Data_Cleaned.csv', index=False)
